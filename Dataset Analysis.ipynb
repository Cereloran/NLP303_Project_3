# %% [markdown]
# # DLE303 Assessment 3 - Main
# ## Rachel Tucker & Michael Cuffe
#
# ## Dependencies:
# - Python 3.12

# %%
# > null 2>&1 removes the output by redirecting it to a file named null
# !pip install pandas                 > null 2>&1
# !pip install matplotlib             > null 2>&1
# !pip install seaborn                > null 2>&1

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Prepare the data

# %%
# Load the dataset
data = pd.read_csv('data/200k_Short_Texts.csv')
data = data.dropna()
data = data.sample(frac=1).reset_index(drop=True)

# %%
# Print the first 10 rows of the dataset
print(data.head(10))
# Out:
#                                                 text  humor
# 0  Elizabeth warren rallies supporters against tr...  False
# 1  If there was any award for laziness, i probabl...   True
# 2  Ugly girls are basically just dudes i'm not al...   True
# 3  These kids are published authors at the ages o...  False
# 4  Bill o'reilly allegedly called woman he was ha...  False
# 5  Got ms? focus on what you can do, not on what ...  False
# 6  Hump day without humping is significantly less...   True
# 7  His campaign in crisis, donald trump turns to ...  False
# 8        What do you call a communist pirate? lutin.   True
# 9  Rosé chocolate exists, and we've officially go...  False

# %%
# Print the shape of the dataset
data['text_length'] = data['text'].apply(len)
# Ratio 16:9 for the graph
plt.figure(figsize=(16, 9))
# Plot the distribution of text lengths
sns.histplot(data['text_length'], bins=50, kde=True)
# Set the title, x-axis label, and y-axis label
plt.title('Distribution of Text Lengths')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# Plot the first 10 rows of the dataset
plt.figure(figsize=(16, 9))
sns.barplot(x=data.index[:10], y=data['text_length'][:10])
plt.title('Text Lengths of the First 10 Rows')
plt.xlabel('Index')
plt.ylabel('Text Length')
plt.show()

# Plot the distribution of True vs False values in the humor column
plt.figure(figsize=(16, 9))
sns.histplot(data['humor'], bins=2, kde=False)
plt.title('Distribution of True vs False Values in Humor Column')
plt.xlabel('Humor')
plt.ylabel('Frequency')
plt.xticks([0, 1], ['False', 'True'])
plt.show()


plt.figure(figsize=(16, 9))
data['humor'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'], labels=['False', 'True'])
plt.title('Distribution of True vs False Values in Humor Column')
plt.ylabel('')
plt.show()
